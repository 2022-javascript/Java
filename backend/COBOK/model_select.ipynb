# %%
import requests
import pymysql
import base64
import sys
import ccxt
from dataread import *
from datetime import datetime
host = "ai-predict.cyyrt9e5hsme.ap-northeast-2.rds.amazonaws.com"
port = 3306
username = "admin"
database = "AI_predict"
password = "825582qaz"

# %%
def connect_RDS(host,port,username,password,database):
    conn = pymysql.connect(host = host,user = username, passwd=password, db=database,
    port=port, use_unicode = True, charset='utf8')
    return conn
today_datetime = datetime.today().strftime("%Y-%m-%d") # YYYY-mm-dd 형태의 시간 출력
ticker = download_data().Usdt_symbol()

# %%
dic = {}
for i in ticker:
        # 데이터 검색 
        conn = connect_RDS(host,port,username,password,database)
        cursor = conn.cursor()

        sql = "SELECT * FROM "+ str(i).replace("/","_")+ " where date = " + '"' + str(today_datetime) + '"'
        cursor.execute(sql) 
        res = cursor.fetchall()
        dic[str(i).replace("/","_")] = res[0][1]
        conn.commit() 
        conn.close()

# %%
dic
# Out:
# {'BTC_USDT': '상승',
#  'ETH_USDT': '하락',
#  'BNB_USDT': '하락',
#  'BCC_USDT': 'data read error',
#  'NEO_USDT': '상승',
#  'LTC_USDT': '하락',
#  'QTUM_USDT': '상승',
#  'ADA_USDT': '상승',
#  'XRP_USDT': '상승',
#  'EOS_USDT': '하락',
#  'TUSD_USDT': '상승',
#  'IOTA_USDT': '상승',
#  'XLM_USDT': '하락',
#  'ONT_USDT': '하락',
#  'TRX_USDT': '상승',
#  'ETC_USDT': '하락',
#  'ICX_USDT': '하락',
#  'VEN_USDT': 'data read error',
#  'NULS_USDT': '상승',
#  'VET_USDT': '상승',
#  'PAX_USDT': 'data read error',
#  'BCH_USDT': '상승',
#  'BSV_USDT': 'data read error',
#  'USDC_USDT': '상승',
#  'LINK_USDT': '상승',
#  'WAVES_USDT': '상승',
#  'BTT_USDT': 'data read error',
#  'USDS_USDT': 'data read error',
#  'ONG_USDT': '상승',
#  'HOT_USDT': '상승',
#  'ZIL_USDT': '하락',
#  'ZRX_USDT': '하락',
#  'FET_USDT': '상승',
#  'BAT_USDT': '상승',
#  'XMR_USDT': '상승',
#  'ZEC_USDT': '하락',
#  'IOST_USDT': '하락',
#  'CELR_USDT': '하락',
#  'DASH_USDT': '하락',
#  'NANO_USDT': 'data read error',
#  'OMG_USDT': '하락',
#  'THETA_USDT': '상승',
#  'ENJ_USDT': '상승',
#  'MITH_USDT': '상승',
#  'MATIC_USDT': '하락',
#  'ATOM_USDT': '하락',
#  'TFUEL_USDT': '하락',
#  'ONE_USDT': '하락',
#  'FTM_USDT': '상승',
#  'ALGO_USDT': '하락',
#  'USDSB_USDT': 'data read error',
#  'GTO_USDT': '상승',
#  'ERD_USDT': 'data read error',
#  'DOGE_USDT': '상승',
#  'DUSK_USDT': '상승',
#  'ANKR_USDT': '상승',
#  'WIN_USDT': '하락',
#  'COS_USDT': '하락',
#  'NPXS_USDT': 'data read error',
#  'COCOS_USDT': '하락',
#  'MTL_USDT': '상승',
#  'TOMO_USDT': '하락',
#  'PERL_USDT': '하락',
#  'DENT_USDT': '상승',
#  'MFT_USDT': '하락',
#  'KEY_USDT': '하락',
#  'STORM_USDT': 'data read error',
#  'DOCK_USDT': '상승',
#  'WAN_USDT': '상승',
#  'FUN_USDT': '하락',
#  'CVC_USDT': '하락',
#  'CHZ_USDT': '상승',
#  'BAND_USDT': '상승',
#  'BUSD_USDT': '상승',
#  'BEAM_USDT': '하락',
#  'XTZ_USDT': '하락',
#  'REN_USDT': '상승',
#  'RVN_USDT': '상승',
#  'HC_USDT': 'data read error',
#  'HBAR_USDT': '상승',
#  'NKN_USDT': '하락',
#  'STX_USDT': '상승',
#  'KAVA_USDT': 'data read error',
#  'ARPA_USDT': 'data read error',
#  'IOTX_USDT': '상승',
#  'RLC_USDT': '하락',
#  'MCO_USDT': 'data read error',
#  'CTXC_USDT': '상승',
#  'TROY_USDT': '하락',
#  'VITE_USDT': '하락',
#  'FTT_USDT': '하락',
#  'EUR_USDT': '상승',
#  'OGN_USDT': '상승',
#  'DREP_USDT': '상승',
#  'BULL_USDT': 'data read error',
#  'BEAR_USDT': 'data read error',
#  'ETHBULL_USDT': 'data read error',
#  'ETHBEAR_USDT': 'data read error',
#  'TCT_USDT': '하락',
#  'WRX_USDT': '상승',
#  'BTS_USDT': '상승',
#  'LSK_USDT': '하락',
#  'BNT_USDT': '상승',
#  'LTO_USDT': '하락',
#  'EOSBULL_USDT': 'data read error',
#  'EOSBEAR_USDT': 'data read error',
#  'XRPBULL_USDT': 'data read error',
#  'XRPBEAR_USDT': 'data read error',
#  'STRAT_USDT': 'data read error',
#  'AION_USDT': '하락',
#  'MBL_USDT': '하락',
#  'COTI_USDT': '상승',
#  'BNBBULL_USDT': 'data read error',
#  'BNBBEAR_USDT': 'data read error',
#  'STPT_USDT': '하락',
#  'WTC_USDT': '하락',
#  'DATA_USDT': '하락',
#  'XZC_USDT': 'data read error',
#  'SOL_USDT': '상승',
#  'CTSI_USDT': '하락',
#  'HIVE_USDT': '상승',
#  'CHR_USDT': '상승',
#  'BTCUP_USDT': '하락',
#  'BTCDOWN_USDT': '하락',
#  'GXS_USDT': 'data read error',
#  'ARDR_USDT': '상승',
#  'LEND_USDT': 'data read error',
#  'MDT_USDT': '상승',
#  'STMX_USDT': '상승',
#  'KNC_USDT': '하락',
#  'REP_USDT': '하락',
#  'LRC_USDT': '상승',
#  'PNT_USDT': '하락',
#  'COMP_USDT': '하락',
#  'BKRW_USDT': 'data read error',
#  'SC_USDT': '상승',
#  'ZEN_USDT': '상승',
#  'SNX_USDT': '하락',
#  'ETHUP_USDT': '하락',
#  'ETHDOWN_USDT': '상승',
#  'ADAUP_USDT': '상승',
#  'ADADOWN_USDT': '하락',
#  'LINKUP_USDT': '하락',
#  'LINKDOWN_USDT': '상승',
#  'VTHO_USDT': '상승',
#  'DGB_USDT': '하락',
#  'GBP_USDT': '상승',
#  'SXP_USDT': '상승',
#  'MKR_USDT': '상승',
#  'DAI_USDT': 'data read error',
#  'DCR_USDT': '상승',
#  'STORJ_USDT': '상승',
#  'BNBUP_USDT': '상승',
#  'BNBDOWN_USDT': '상승',
#  'XTZUP_USDT': 'data read error',
#  'XTZDOWN_USDT': 'data read error',
#  'MANA_USDT': '상승',
#  'AUD_USDT': '상승',
#  'YFI_USDT': '하락',
#  'BAL_USDT': '하락',
#  'BLZ_USDT': '상승',
#  'IRIS_USDT': '상승',
#  'KMD_USDT': '상승',
#  'JST_USDT': '하락',
#  'SRM_USDT': '상승',
#  'ANT_USDT': '하락',
#  'CRV_USDT': '하락',
#  'SAND_USDT': '상승',
#  'OCEAN_USDT': '상승',
#  'NMR_USDT': '하락',
#  'DOT_USDT': '하락',
#  'LUNA_USDT': '상승',
#  'RSR_USDT': '상승',
#  'PAXG_USDT': '상승',
#  'WNXM_USDT': '상승',
#  'TRB_USDT': '하락',
#  'BZRX_USDT': 'data read error',
#  'SUSHI_USDT': '상승',
#  'YFII_USDT': '상승',
#  'KSM_USDT': '상승',
#  'EGLD_USDT': '하락',
#  'DIA_USDT': '상승',
#  'RUNE_USDT': '상승',
#  'FIO_USDT': '하락',
#  'UMA_USDT': '하락',
#  'EOSUP_USDT': 'data read error',
#  'EOSDOWN_USDT': 'data read error',
#  'TRXUP_USDT': '상승',
#  'TRXDOWN_USDT': '상승',
#  'XRPUP_USDT': '하락',
#  'XRPDOWN_USDT': '상승',
#  'DOTUP_USDT': '상승',
#  'DOTDOWN_USDT': '상승',
#  'BEL_USDT': '하락',
#  'WING_USDT': '상승',
#  'LTCUP_USDT': 'data read error',
#  'LTCDOWN_USDT': 'data read error',
#  'UNI_USDT': '하락',
#  'NBS_USDT': '상승',
#  'OXT_USDT': '상승',
#  'SUN_USDT': '상승',
#  'AVAX_USDT': '하락',
#  'HNT_USDT': '상승',
#  'FLM_USDT': '상승',
#  'UNIUP_USDT': 'data read error',
#  'UNIDOWN_USDT': 'data read error',
#  'ORN_USDT': '상승',
#  'UTK_USDT': '하락',
#  'XVS_USDT': '하락',
#  'ALPHA_USDT': '하락',
#  'AAVE_USDT': '하락',
#  'NEAR_USDT': '상승',
#  'SXPUP_USDT': 'data read error',
#  'SXPDOWN_USDT': 'data read error',
#  'FIL_USDT': '상승',
#  'FILUP_USDT': 'data read error',
#  'FILDOWN_USDT': 'data read error',
#  'YFIUP_USDT': 'data read error',
#  'YFIDOWN_USDT': 'data read error',
#  'INJ_USDT': '상승',
#  'AUDIO_USDT': '상승',
#  'CTK_USDT': '상승',
#  'BCHUP_USDT': 'data read error',
#  'BCHDOWN_USDT': 'data read error',
#  'AKRO_USDT': '상승',
#  'AXS_USDT': '상승',
#  'HARD_USDT': '상승',
#  'DNT_USDT': '하락',
#  'STRAX_USDT': '상승',
#  'UNFI_USDT': '하락',
#  'ROSE_USDT': '상승',
#  'AVA_USDT': '하락',
#  'XEM_USDT': '하락',
#  'AAVEUP_USDT': 'data read error',
#  'AAVEDOWN_USDT': 'data read error',
#  'SKL_USDT': '상승',
#  'SUSD_USDT': 'data read error',
#  'SUSHIUP_USDT': 'data read error',
#  'SUSHIDOWN_USDT': 'data read error',
#  'XLMUP_USDT': 'data read error',
#  'XLMDOWN_USDT': 'data read error',
#  'GRT_USDT': '상승',
#  'JUV_USDT': '하락',
#  'PSG_USDT': '하락',
#  '1INCH_USDT': '상승',
#  'REEF_USDT': '상승',
#  'OG_USDT': '하락',
#  'ATM_USDT': '하락',
#  'ASR_USDT': '하락',
#  'CELO_USDT': '상승',
#  'RIF_USDT': '하락',
#  'BTCST_USDT': '하락',
#  'TRU_USDT': '상승',
#  'CKB_USDT': '상승',
#  'TWT_USDT': '하락',
#  'FIRO_USDT': '상승',
#  'LIT_USDT': '상승',
#  'SFP_USDT': '하락',
#  'DODO_USDT': '하락',
#  'CAKE_USDT': '상승',
#  'ACM_USDT': '하락',
#  'BADGER_USDT': '상승',
#  'FIS_USDT': '하락',
#  'OM_USDT': '하락',
#  'POND_USDT': '상승',
#  'DEGO_USDT': '하락',
#  'ALICE_USDT': '상승',
#  'LINA_USDT': '하락',
#  'PERP_USDT': '상승',
#  'RAMP_USDT': '하락',
#  'SUPER_USDT': '상승',
#  'CFX_USDT': '하락',
#  'EPS_USDT': 'data scale error',
#  'AUTO_USDT': '하락',
#  'TKO_USDT': '하락',
#  'PUNDIX_USDT': '상승',
#  'TLM_USDT': '상승',
#  '1INCHUP_USDT': 'data read error',
#  '1INCHDOWN_USDT': 'data read error',
#  'BTG_USDT': '상승',
#  'MIR_USDT': '상승',
#  'BAR_USDT': '하락',
#  'FORTH_USDT': '상승',
#  'BAKE_USDT': '하락',
#  'BURGER_USDT': '상승',
#  'SLP_USDT': '하락',
#  'SHIB_USDT': '상승',
#  'ICP_USDT': '상승',
#  'AR_USDT': '하락',
#  'POLS_USDT': '상승',
#  'MDX_USDT': '상승',
#  'MASK_USDT': '상승',
#  'LPT_USDT': '하락',
#  'NU_USDT': 'data read error',
#  'XVG_USDT': '하락',
#  'ATA_USDT': '상승',
#  'GTC_USDT': '하락',
#  'TORN_USDT': '상승',
#  'KEEP_USDT': 'data read error',
#  'ERN_USDT': '상승',
#  'KLAY_USDT': '상승',
#  'PHA_USDT': '상승',
#  'BOND_USDT': '상승',
#  'MLN_USDT': '상승',
#  'DEXE_USDT': '상승',
#  'C98_USDT': '상승',
#  'CLV_USDT': '하락',
#  'QNT_USDT': '상승',
#  'FLOW_USDT': '하락',
#  'TVK_USDT': '하락',
#  'MINA_USDT': '상승',
#  'RAY_USDT': '하락',
#  'FARM_USDT': '하락',
#  'ALPACA_USDT': '하락',
#  'QUICK_USDT': '하락',
#  'MBOX_USDT': '하락',
#  'FOR_USDT': '상승',
#  'REQ_USDT': '하락',
#  'GHST_USDT': '상승',
#  'WAXP_USDT': '하락',
#  'TRIBE_USDT': '상승',
#  'GNO_USDT': '하락',
#  'XEC_USDT': '상승',
#  'ELF_USDT': '상승',
#  'DYDX_USDT': '하락',
#  'POLY_USDT': '하락',
#  'IDEX_USDT': '하락',
#  'VIDT_USDT': '상승',
#  'USDP_USDT': '상승',
#  'GALA_USDT': '상승',
#  'ILV_USDT': '상승',
#  'YGG_USDT': '하락',
#  'SYS_USDT': '상승',
#  'DF_USDT': '상승',
#  'FIDA_USDT': '상승',
#  'FRONT_USDT': '상승',
#  'CVP_USDT': '상승',
#  'AGLD_USDT': '하락',
#  'RAD_USDT': '하락',
#  'BETA_USDT': '하락',
#  'RARE_USDT': '상승',
#  'LAZIO_USDT': '하락',
#  'CHESS_USDT': '상승',
#  'ADX_USDT': '하락',
#  'AUCTION_USDT': '하락',
#  'DAR_USDT': '상승',
#  'BNX_USDT': '상승',
#  'RGT_USDT': 'data read error',
#  'MOVR_USDT': '하락',
#  'CITY_USDT': '상승',
#  'ENS_USDT': '하락',
#  'KP3R_USDT': '하락',
#  'QI_USDT': '상승',
#  'PORTO_USDT': '하락',
#  'POWR_USDT': '하락',
#  'VGX_USDT': '하락',
#  'JASMY_USDT': '하락',
#  'AMP_USDT': '상승',
#  'PLA_USDT': '상승',
#  'PYR_USDT': '상승',
#  'RNDR_USDT': '하락',
#  'ALCX_USDT': '하락',
#  'SANTOS_USDT': '하락',
#  'MC_USDT': '하락',
#  'ANY_USDT': 'data read error',
#  'BICO_USDT': '상승',
#  'FLUX_USDT': '하락',
#  'FXS_USDT': '하락',
#  'VOXEL_USDT': '하락',
#  'HIGH_USDT': '하락',
#  'CVX_USDT': '상승',
#  'PEOPLE_USDT': '상승',
#  'OOKI_USDT': '하락',
#  'SPELL_USDT': '하락',
#  'UST_USDT': 'data scale error',
#  'JOE_USDT': '상승',
#  'ACH_USDT': '하락',
#  'IMX_USDT': '상승',
#  'GLMR_USDT': '하락',
#  'LOKA_USDT': '상승',
#  'SCRT_USDT': '하락',
#  'API3_USDT': '하락',
#  'BTTC_USDT': '하락',
#  'ACA_USDT': '상승',
#  'ANC_USDT': '상승',
#  'XNO_USDT': '하락',
#  'WOO_USDT': '상승',
#  'ALPINE_USDT': '하락',
#  'T_USDT': '하락',
#  'ASTR_USDT': '상승',
#  'NBT_USDT': '상승',
#  'GMT_USDT': '상승',
#  'KDA_USDT': '하락',
#  'APE_USDT': '하락',
#  'BSW_USDT': '하락',
#  'BIFI_USDT': '하락',
#  'MULTI_USDT': '하락',
#  'STEEM_USDT': '하락',
#  'MOB_USDT': '하락',
#  'NEXO_USDT': '하락',
#  'REI_USDT': '상승',
#  'GAL_USDT': '상승',
#  'LDO_USDT': '하락',
#  'EPX_USDT': '하락',
#  'OP_USDT': '상승',
#  'LEVER_USDT': 'model predict error'}

# %%
ticker
# Out:
# ['BTC/USDT',
#  'ETH/USDT',
#  'BNB/USDT',
#  'BCC/USDT',
#  'NEO/USDT',
#  'LTC/USDT',
#  'QTUM/USDT',
#  'ADA/USDT',
#  'XRP/USDT',
#  'EOS/USDT',
#  'TUSD/USDT',
#  'IOTA/USDT',
#  'XLM/USDT',
#  'ONT/USDT',
#  'TRX/USDT',
#  'ETC/USDT',
#  'ICX/USDT',
#  'VEN/USDT',
#  'NULS/USDT',
#  'VET/USDT',
#  'PAX/USDT',
#  'BCH/USDT',
#  'BSV/USDT',
#  'USDC/USDT',
#  'LINK/USDT',
#  'WAVES/USDT',
#  'BTT/USDT',
#  'USDS/USDT',
#  'ONG/USDT',
#  'HOT/USDT',
#  'ZIL/USDT',
#  'ZRX/USDT',
#  'FET/USDT',
#  'BAT/USDT',
#  'XMR/USDT',
#  'ZEC/USDT',
#  'IOST/USDT',
#  'CELR/USDT',
#  'DASH/USDT',
#  'NANO/USDT',
#  'OMG/USDT',
#  'THETA/USDT',
#  'ENJ/USDT',
#  'MITH/USDT',
#  'MATIC/USDT',
#  'ATOM/USDT',
#  'TFUEL/USDT',
#  'ONE/USDT',
#  'FTM/USDT',
#  'ALGO/USDT',
#  'USDSB/USDT',
#  'GTO/USDT',
#  'ERD/USDT',
#  'DOGE/USDT',
#  'DUSK/USDT',
#  'ANKR/USDT',
#  'WIN/USDT',
#  'COS/USDT',
#  'NPXS/USDT',
#  'COCOS/USDT',
#  'MTL/USDT',
#  'TOMO/USDT',
#  'PERL/USDT',
#  'DENT/USDT',
#  'MFT/USDT',
#  'KEY/USDT',
#  'STORM/USDT',
#  'DOCK/USDT',
#  'WAN/USDT',
#  'FUN/USDT',
#  'CVC/USDT',
#  'CHZ/USDT',
#  'BAND/USDT',
#  'BUSD/USDT',
#  'BEAM/USDT',
#  'XTZ/USDT',
#  'REN/USDT',
#  'RVN/USDT',
#  'HC/USDT',
#  'HBAR/USDT',
#  'NKN/USDT',
#  'STX/USDT',
#  'KAVA/USDT',
#  'ARPA/USDT',
#  'IOTX/USDT',
#  'RLC/USDT',
#  'MCO/USDT',
#  'CTXC/USDT',
#  'TROY/USDT',
#  'VITE/USDT',
#  'FTT/USDT',
#  'EUR/USDT',
#  'OGN/USDT',
#  'DREP/USDT',
#  'BULL/USDT',
#  'BEAR/USDT',
#  'ETHBULL/USDT',
#  'ETHBEAR/USDT',
#  'TCT/USDT',
#  'WRX/USDT',
#  'BTS/USDT',
#  'LSK/USDT',
#  'BNT/USDT',
#  'LTO/USDT',
#  'EOSBULL/USDT',
#  'EOSBEAR/USDT',
#  'XRPBULL/USDT',
#  'XRPBEAR/USDT',
#  'STRAT/USDT',
#  'AION/USDT',
#  'MBL/USDT',
#  'COTI/USDT',
#  'BNBBULL/USDT',
#  'BNBBEAR/USDT',
#  'STPT/USDT',
#  'WTC/USDT',
#  'DATA/USDT',
#  'XZC/USDT',
#  'SOL/USDT',
#  'CTSI/USDT',
#  'HIVE/USDT',
#  'CHR/USDT',
#  'BTCUP/USDT',
#  'BTCDOWN/USDT',
#  'GXS/USDT',
#  'ARDR/USDT',
#  'LEND/USDT',
#  'MDT/USDT',
#  'STMX/USDT',
#  'KNC/USDT',
#  'REP/USDT',
#  'LRC/USDT',
#  'PNT/USDT',
#  'COMP/USDT',
#  'BKRW/USDT',
#  'SC/USDT',
#  'ZEN/USDT',
#  'SNX/USDT',
#  'ETHUP/USDT',
#  'ETHDOWN/USDT',
#  'ADAUP/USDT',
#  'ADADOWN/USDT',
#  'LINKUP/USDT',
#  'LINKDOWN/USDT',
#  'VTHO/USDT',
#  'DGB/USDT',
#  'GBP/USDT',
#  'SXP/USDT',
#  'MKR/USDT',
#  'DAI/USDT',
#  'DCR/USDT',
#  'STORJ/USDT',
#  'BNBUP/USDT',
#  'BNBDOWN/USDT',
#  'XTZUP/USDT',
#  'XTZDOWN/USDT',
#  'MANA/USDT',
#  'AUD/USDT',
#  'YFI/USDT',
#  'BAL/USDT',
#  'BLZ/USDT',
#  'IRIS/USDT',
#  'KMD/USDT',
#  'JST/USDT',
#  'SRM/USDT',
#  'ANT/USDT',
#  'CRV/USDT',
#  'SAND/USDT',
#  'OCEAN/USDT',
#  'NMR/USDT',
#  'DOT/USDT',
#  'LUNA/USDT',
#  'RSR/USDT',
#  'PAXG/USDT',
#  'WNXM/USDT',
#  'TRB/USDT',
#  'BZRX/USDT',
#  'SUSHI/USDT',
#  'YFII/USDT',
#  'KSM/USDT',
#  'EGLD/USDT',
#  'DIA/USDT',
#  'RUNE/USDT',
#  'FIO/USDT',
#  'UMA/USDT',
#  'EOSUP/USDT',
#  'EOSDOWN/USDT',
#  'TRXUP/USDT',
#  'TRXDOWN/USDT',
#  'XRPUP/USDT',
#  'XRPDOWN/USDT',
#  'DOTUP/USDT',
#  'DOTDOWN/USDT',
#  'BEL/USDT',
#  'WING/USDT',
#  'LTCUP/USDT',
#  'LTCDOWN/USDT',
#  'UNI/USDT',
#  'NBS/USDT',
#  'OXT/USDT',
#  'SUN/USDT',
#  'AVAX/USDT',
#  'HNT/USDT',
#  'FLM/USDT',
#  'UNIUP/USDT',
#  'UNIDOWN/USDT',
#  'ORN/USDT',
#  'UTK/USDT',
#  'XVS/USDT',
#  'ALPHA/USDT',
#  'AAVE/USDT',
#  'NEAR/USDT',
#  'SXPUP/USDT',
#  'SXPDOWN/USDT',
#  'FIL/USDT',
#  'FILUP/USDT',
#  'FILDOWN/USDT',
#  'YFIUP/USDT',
#  'YFIDOWN/USDT',
#  'INJ/USDT',
#  'AUDIO/USDT',
#  'CTK/USDT',
#  'BCHUP/USDT',
#  'BCHDOWN/USDT',
#  'AKRO/USDT',
#  'AXS/USDT',
#  'HARD/USDT',
#  'DNT/USDT',
#  'STRAX/USDT',
#  'UNFI/USDT',
#  'ROSE/USDT',
#  'AVA/USDT',
#  'XEM/USDT',
#  'AAVEUP/USDT',
#  'AAVEDOWN/USDT',
#  'SKL/USDT',
#  'SUSD/USDT',
#  'SUSHIUP/USDT',
#  'SUSHIDOWN/USDT',
#  'XLMUP/USDT',
#  'XLMDOWN/USDT',
#  'GRT/USDT',
#  'JUV/USDT',
#  'PSG/USDT',
#  '1INCH/USDT',
#  'REEF/USDT',
#  'OG/USDT',
#  'ATM/USDT',
#  'ASR/USDT',
#  'CELO/USDT',
#  'RIF/USDT',
#  'BTCST/USDT',
#  'TRU/USDT',
#  'CKB/USDT',
#  'TWT/USDT',
#  'FIRO/USDT',
#  'LIT/USDT',
#  'SFP/USDT',
#  'DODO/USDT',
#  'CAKE/USDT',
#  'ACM/USDT',
#  'BADGER/USDT',
#  'FIS/USDT',
#  'OM/USDT',
#  'POND/USDT',
#  'DEGO/USDT',
#  'ALICE/USDT',
#  'LINA/USDT',
#  'PERP/USDT',
#  'RAMP/USDT',
#  'SUPER/USDT',
#  'CFX/USDT',
#  'EPS/USDT',
#  'AUTO/USDT',
#  'TKO/USDT',
#  'PUNDIX/USDT',
#  'TLM/USDT',
#  '1INCHUP/USDT',
#  '1INCHDOWN/USDT',
#  'BTG/USDT',
#  'MIR/USDT',
#  'BAR/USDT',
#  'FORTH/USDT',
#  'BAKE/USDT',
#  'BURGER/USDT',
#  'SLP/USDT',
#  'SHIB/USDT',
#  'ICP/USDT',
#  'AR/USDT',
#  'POLS/USDT',
#  'MDX/USDT',
#  'MASK/USDT',
#  'LPT/USDT',
#  'NU/USDT',
#  'XVG/USDT',
#  'ATA/USDT',
#  'GTC/USDT',
#  'TORN/USDT',
#  'KEEP/USDT',
#  'ERN/USDT',
#  'KLAY/USDT',
#  'PHA/USDT',
#  'BOND/USDT',
#  'MLN/USDT',
#  'DEXE/USDT',
#  'C98/USDT',
#  'CLV/USDT',
#  'QNT/USDT',
#  'FLOW/USDT',
#  'TVK/USDT',
#  'MINA/USDT',
#  'RAY/USDT',
#  'FARM/USDT',
#  'ALPACA/USDT',
#  'QUICK/USDT',
#  'MBOX/USDT',
#  'FOR/USDT',
#  'REQ/USDT',
#  'GHST/USDT',
#  'WAXP/USDT',
#  'TRIBE/USDT',
#  'GNO/USDT',
#  'XEC/USDT',
#  'ELF/USDT',
#  'DYDX/USDT',
#  'POLY/USDT',
#  'IDEX/USDT',
#  'VIDT/USDT',
#  'USDP/USDT',
#  'GALA/USDT',
#  'ILV/USDT',
#  'YGG/USDT',
#  'SYS/USDT',
#  'DF/USDT',
#  'FIDA/USDT',
#  'FRONT/USDT',
#  'CVP/USDT',
#  'AGLD/USDT',
#  'RAD/USDT',
#  'BETA/USDT',
#  'RARE/USDT',
#  'LAZIO/USDT',
#  'CHESS/USDT',
#  'ADX/USDT',
#  'AUCTION/USDT',
#  'DAR/USDT',
#  'BNX/USDT',
#  'RGT/USDT',
#  'MOVR/USDT',
#  'CITY/USDT',
#  'ENS/USDT',
#  'KP3R/USDT',
#  'QI/USDT',
#  'PORTO/USDT',
#  'POWR/USDT',
#  'VGX/USDT',
#  'JASMY/USDT',
#  'AMP/USDT',
#  'PLA/USDT',
#  'PYR/USDT',
#  'RNDR/USDT',
#  'ALCX/USDT',
#  'SANTOS/USDT',
#  'MC/USDT',
#  'ANY/USDT',
#  'BICO/USDT',
#  'FLUX/USDT',
#  'FXS/USDT',
#  'VOXEL/USDT',
#  'HIGH/USDT',
#  'CVX/USDT',
#  'PEOPLE/USDT',
#  'OOKI/USDT',
#  'SPELL/USDT',
#  'UST/USDT',
#  'JOE/USDT',
#  'ACH/USDT',
#  'IMX/USDT',
#  'GLMR/USDT',
#  'LOKA/USDT',
#  'SCRT/USDT',
#  'API3/USDT',
#  'BTTC/USDT',
#  'ACA/USDT',
#  'ANC/USDT',
#  'XNO/USDT',
#  'WOO/USDT',
#  'ALPINE/USDT',
#  'T/USDT',
#  'ASTR/USDT',
#  'NBT/USDT',
#  'GMT/USDT',
#  'KDA/USDT',
#  'APE/USDT',
#  'BSW/USDT',
#  'BIFI/USDT',
#  'MULTI/USDT',
#  'STEEM/USDT',
#  'MOB/USDT',
#  'NEXO/USDT',
#  'REI/USDT',
#  'GAL/USDT',
#  'LDO/USDT',
#  'EPX/USDT',
#  'OP/USDT',
#  'LEVER/USDT']
